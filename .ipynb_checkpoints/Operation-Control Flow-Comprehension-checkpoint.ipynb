# %%
x3 = [1, 2, 3]
y3 = [1, 2, 3]

# %%
print(x3 == y3)
# Out:
# True

# %%
print(x3 != y3)
# Out:
# False

# %%
print(x3 is y3)
# Out:
# False

# %%
print(x3 is not y3)
# Out:
# True

# %%
x4 = []
y4 = []

# %%
print(x4 is y4)
# Out:
# False

# %%
x4.append(10)

# %%
x4, y4
# Out:
# ([10], [])

# %%
y5 = x4

# %%
print(y5 is x4)
# Out:
# True

# %%
print(y5,x4)
# Out:
# [10, 50, 50] [10, 50, 50]

# %%
x4.append(50)

# %%
print(y5,x4)
# Out:
# [10, 50, 50, 50] [10, 50, 50, 50]

# %%
x = {1:'a', 2:'b','tiga': 3}
print(1 in x)
# Out:
# True

# %%
print(2 in x)
# Out:
# True

# %%
print('tiga' in x[2])
# Out:
# False

# %%
x['tiga']
# Out:
# 3

# %%
print('a' in x['tiga'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7628/1235531082.py in <module>
# ----> 1 print('a' in x['tiga'])
#
# TypeError: argument of type 'int' is not iterable

# %% [markdown]
# ## Input

# %%
name = input("Tolong masukkan nama: ")
# Out:
# Tolong masukkan nama: dino

# %%
print(name)
# Out:
# dino

# %%
umur = float(input("Masukkan umur kamu ya: "))
# Out:
# Masukkan umur kamu ya: 23

# %%
print(umur, type(umur))
# Out:
# 23.0 <class 'float'>

# %% [markdown]
# ## If else

# %%
b = 30
a = 10
c = a + b #c = 10 + 10 = 20

if(a == b and c > a):
    print('A dan B sama atau C lebih besar dari A')
elif (a > b):
    print('A lebih besar dari B')
elif(b > a):
    print('B Lebih besar dari A')
else:
    print('A dan B beda')
# Out:
# B Lebih besar dari A

# %% [markdown]
# ## For Loop

# %%
for k in range(0,10):
    print("Hai")
# Out:
# Hai
# Hai
# Hai
# Hai
# Hai
# Hai
# Hai
# Hai
# Hai
# Hai

# %%
list1 = ['apel', 'banana', 'mango', 'star fruit', 'durian']

# %%
for ele in list1 :
    print(ele)
# Out:
# apel
# banana
# mango
# star fruit
# durian

# %%
list2 = [1,2,3,4,10,23,12]

for ele in list2:
    print(ele+1)
# Out:
# 2
# 3
# 4
# 5
# 11
# 24
# 13

# %% [markdown]
# ## While Loop

# %%
angka = int(input("Masukkan angka awal: "))

while(angka<30):
    print('Angka bertambah')
    angka = angka+1
# Out:
# Masukkan angka awal: 20
# Angka bertambah
# Angka bertambah
# Angka bertambah
# Angka bertambah
# Angka bertambah
# Angka bertambah
# Angka bertambah
# Angka bertambah
# Angka bertambah
# Angka bertambah

# %%
kata = input("Masukkan kata : ")

while((kata!='berhenti') and (kata!='Berhenti')):
    print(kata)
    print('Belum kata berhenti')
    kata = input("Masukkan kata : ")
# Out:
# Masukkan kata : as
# as
# Belum kata berhenti
# Masukkan kata : berhent
# berhent
# Belum kata berhenti
# Masukkan kata : berhenti

# %%
kata = input("Masukkan kata : ")

while(True):
    try:
        kata = int(kata)
    except:
        break
    else:
        kata = input("Masukkan kata : ")
# Out:
# Masukkan kata : 123
# Masukkan kata : 123
# Masukkan kata : 123
# Masukkan kata : 45123123
# Masukkan kata : kata

# %% [markdown]
# ## break, continue, and pass

# %%
list2 = [1,2,3,4,10,23,12]

for ele in list2:
    if(ele==10):
        break
    else:
        print(ele)
# Out:
# 1
# 2
# 3
# 4

# %%
list2 = [1,2,3,4,10,23,12]

for ele in list2:
    if(ele==10):
        continue
    else:
        print(ele)
# Out:
# 1
# 2
# 3
# 4
# 23
# 12

# %%
for ele in list2:
    if(ele==10):
        pass
    else:
        print(ele)
# Out:
# 1
# 2
# 3
# 4
# 23
# 12

# %%
def tambah(angka):
    pass

# %%
tambah(10)

# %% [markdown]
# ## List Comprehension

# %%
list2 = [1,2,3,4,10,23,12]
list2
# Out:
# [1, 2, 3, 4, 10, 23, 12]

# %%
new_list = [i**2 for i in list2]

# %%
new_list
# Out:
# [1, 4, 9, 16, 100, 529, 144]

# %%
new_list=[]

# %%
for ele in list2:
    new_list.append(ele**2)

# %%
new_list
# Out:
# [1, 4, 9, 16, 100, 529, 144]

# %% [markdown]
# ## Dictionary Comprehension

# %%
dict1 = {"apple":[30,10], "mango":25, "banana":40, "grapes":15}
dict1
# Out:
# {'apple': [30, 10], 'mango': 25, 'banana': 40, 'grapes': 15}

# %%
#new_dict = {key:value+10 for (key,value) in dict1.items()}

# %%
new_dict
# Out:
# {'apple': 40, 'mango': 35, 'banana': 50, 'grapes': 25}

# %%
dict1.items()
# Out:
# dict_items([('apple', [30, 10]), ('mango', 25), ('banana', 40), ('grapes', 15)])

# %%
dict1.values()
# Out:
# dict_values([[30, 10], 25, 40, 15])

# %%
dict1.keys()
# Out:
# dict_keys(['apple', 'mango', 'banana', 'grapes'])

# %%
for i in dict1.items():
    print(i)
# Out:
# ('apple', 30)
# ('mango', 25)
# ('banana', 40)
# ('grapes', 15)

# %%
for (key,value) in dict1.items():
    print(key, value)
# Out:
# apple 30
# mango 25
# banana 40
# grapes 15

# %%
list2
# Out:
# [1, 2, 3, 4, 10, 23, 12]

# %%
new_list2 = list2.copy()
