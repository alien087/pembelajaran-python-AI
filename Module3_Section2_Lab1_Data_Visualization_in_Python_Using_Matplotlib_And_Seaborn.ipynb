# %% [markdown]
# # Module 3: Data Analytics With Python - Applied Statistics

# %% [markdown]
# ## Lab 1: Data Visualization in Python Using Matplotlib and Seaborn

# %% [markdown]
# Data Visualization is used to communicate information clearly and efficiently to users by the usage of information graphics such as tables and charts. It helps users in analyzing a large amount of data in a simpler way. It makes complex data more accessible, understandable, and usable.
#
#
# *   Matplotlib is one of the most popular Python packages used for data visualization.
#
# *   It is a cross-platform library for making 2D plots from data in arrays.
#
# *   Matplotlib is written in Python and makes use of NumPy, the numerical mathematics extension of Python.

# %% [markdown]
# ## Objective
# ***
#
# * Line Plots
#     * Controlling Line Patterns and Colors
# * Analysing Outliers
# * Set Axis, Labels, and Legend Properties
# * Subplots
# * Types of Plots in Seaborn
#   * Scatter Plot
#   * Line Plot
#   * Bar Plot
#   * Box Plots
#   * Distribution Plots
#     * Heatmaps
#     * Swarmplot
#     * Count plot
#     * Density plot

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Line Plots
# ***
# Line plots are also called dot plots. They are used to show the relationship between two variables.

# %%
# Line Plots
x = [1,2,3,4,5]
y = [6,7,8,9,10]

plt.plot(x,y)
plt.show()

# %%
harga_rumah = [2500, 2700, 2300, 3000, 3100]
tahun = [2019, 2020, 2021, 2022, 2023]

plt.plot(tahun, harga_rumah)
plt.show()

# %% [markdown]
# ### Controlling Line Patterns and Colors
# ***
# Following are the linestyles available in matplotlib:
#
# Using linestyle Argument:
#
# * Solid(-)
#
# * Dashed(--)
#
# * Dotted(:)
#
# * Dashdot(-.)
#
# * None(‘ ’)

# %%
plt.plot([1,2,8],[1.4,3,8.6], 'h-.')
plt.plot([9,8,1],[1.4,3,5.6], ls='--', color="blue")
plt.show()

# %% [markdown]
# ### Set Axis, Labels, and Legend Properties
# ***

# %% [markdown]
# Following are some more attributes of function legend() :
#
# *    shadow: [None or bool] Whether to draw a shadow behind the legend.It’s Default value is None.
#
# *    fontsize: The font size of the legend.If the value is numeric the size will be the absolute font size in points.
#
# *    facecolor: [None or “inherit” or color] The legend’s background color.
#
# *    edgecolor: [None or “inherit” or color] The legend’s background patch edge color.

# %%
plt.plot([1,2,3,4,5,6,7,8,12],[8,7,6,5,4,3,2,1,9],'k_-', label="Black Line")
plt.plot([1,2,3],[3,2,1],'r_-', label="Red Line") 

# Show Legend
plt.legend(fontsize=15, shadow=True, facecolor="yellow", edgecolor='blue')

plt.xlim(1,15) #Setting X-Axis limits
plt.ylim(1,10) #Setting Y-Axis limits
plt.show()

# %% [markdown]
# ### Subplots
# ***
# A subplot () function is a wrapper function which allows the programmer to plot more than one graph in a single figure by just calling it once.
#
# We can draw multiple plots in matplotlib in two ways. One is by using subplot() function and other by superimposition of second graph on the first.

# %%
# importing math
import math
  
# Creating some random data
X = np.arange(0, math.pi*2, 0.05)
Y1 = np.sin(X)
Y2 = np.cos(X)
  
# Initialise the subplot function using number of rows and columns
figure, axis = plt.subplots(nrows=1, ncols=2,figsize=(13,5))
  
# For Sine Function
axis[0].plot(X, Y1)
axis[0].set_title("Sine Function")
  
# For Cosine Function
axis[1].plot(X, Y2)
axis[1].set_title("Cosine Function")

plt.show()

# %%
# importing math
import math
  
# Creating some random data
X = np.arange(0, math.pi*2, 0.05)
Y1 = np.sin(X)
Y2 = np.cos(X)
  
# Initialise the subplot function using number of rows and columns
figure, axis = plt.subplots(nrows=2, ncols=2,figsize=(13,8))
  
# For Sine Function
axis[0][0].plot(X, Y1)
axis[0][0].set_title("Sine Function")
  
# For Cosine Function
axis[0][1].plot(X, Y2)
axis[0][1].set_title("Cosine Function")

# For random plot
axis[1][0].plot([1,2,3],[3,2,1],'r_-', label="Red Line") 
axis[1][0].set_title("Random Graph")
plt.show()

# %% [markdown]
# ### Types of Plots in Seaborn
# ***

# %% [markdown]
# Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
#
# Types of Plots in Seaborn Covered here are-
#
# * Scatter Plot
# * Line Plot
# * Bar Plot
# * Box Plots
# * Distribution Plots
#   * Heatmaps
#   * Swarmplot
#   * Count plot
#   * Density plot

# %% [markdown]
# We are going to use the 'tips' dataset here form seaborn library.

# %%
import seaborn as sns
df=sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### Scatter Plot
# ***
# The are used to identify how one variable changes with other.

# %%
sns.scatterplot(x=df['total_bill'], y=df['tip'])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x=df['sex'], y=df['tip'])
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %% [markdown]
# ###  Line Plot
# ***
#
# They are most useful for showing trends and for identifying whether two variables relate to (or "correlate with") one another.

# %%
#Melakuakn aggregasi (melakukan groupping berdasarkan hari, kemudian menghitung rata-rata total_bill perhari)
df1=df.groupby('day')['total_bill'].mean()
df1
# Out:
# day
# Thur    17.682742
# Fri     17.151579
# Sat     20.441379
# Sun     21.410000
# Name: total_bill, dtype: float64

# %%
#df1.index menyimpan harinnya
df1.index
# Out:
# CategoricalIndex(['Thur', 'Fri', 'Sat', 'Sun'], categories=['Thur', 'Fri', 'Sat', 'Sun'], ordered=False, dtype='category', name='day')

# %%
#df1.values menyimpan rata-rata total_bill perhari
df1.values
# Out:
# array([17.68274194, 17.15157895, 20.44137931, 21.41      ])

# %%
sns.lineplot(x=df1.index, y=df1.values)

plt.ylabel("Average Bill")
# Out:
# Text(0, 0.5, 'Average Bill')

# %% [markdown]
# ### Bar Plot
# ***
#
# The purpose of a bar graph is to convey relational information quickly as the bars display the quantity for a particular category.

# %%
#Melakuakn aggregasi (melakukan groupping berdasarkan jenis kelamin, kemudian menghitung rata-rata tip yg diberikan
#berdasarkan Jenis kelamin)

df1=df.groupby('sex')['tip'].mean()
df1
# Out:
# sex
# Male      3.089618
# Female    2.833448
# Name: tip, dtype: float64

# %%
sns.barplot(x=df1.index, y=df1.values)
plt.ylabel("Mean Tip")
plt.title("Perbandingan Rata Rata Tip Perempuan dan Laki-laki")
plt.show()

# %%
#Melakuakn aggregasi (melakukan groupping berdasarkan jenis kelamin, kemudian menghitung total customer yg memberikan tip
#berdasarkan Jenis kelamin)

df1=df.groupby('sex')['tip'].count()
df1
# Out:
# sex
# Male      157
# Female     87
# Name: tip, dtype: int64

# %%
sns.barplot(x=df1.index, y=df1.values)
plt.ylabel("Count Tip")
plt.title("Perbandingan pelanggan Pria dan Wanita yang memberikan Tip")
plt.show()

# %% [markdown]
# ### Box Plot
# ***
# Box plots divide the data into sections that each contain approximately 25% of the data in that set. Box plots are useful as they provide a visual summary of the data enabling us to quickly identify mean values, the dispersion of the data set, and signs of skewness.

# %%
# Plots the box plot of tips
sns.boxplot(data=df['tip'])
plt.xlabel("TIPS")
plt.show()

# %% [markdown]
# ### Distribution Plots
# ***

# %% [markdown]
# #### Histplot
# It is used basically for univariant set of observations and visualizes it through a  histogram i.e. only one observation and hence we choose one particular column of the dataset.

# %%
sns.histplot(df['tip'], alpha=0.7)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %% [markdown]
# #### Histplot with KDE

# %%
sns.histplot(df['tip'],alpha=0.3,kde=True,stat='density')
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %% [markdown]
# ### Jointplot
# ***
#
# It is used to draw a plot of two variables with bivariate and univariate graphs. It basically combines two different plots.

# %%
sns.jointplot(x ='total_bill', y ='tip', data = df)

# %% [markdown]
# ### Pairplot
# ***
#
# To plot multiple pairwise bivariate distributions in a dataset, you can use the pairplot() function.

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, hue="sex")

# %% [markdown]
# ### Heatmaps
# ***
#
# A heat map (or heatmap) is a data visualization technique that shows magnitude of a phenomenon as color in two dimensions. The variation in color may be by hue or intensity, giving obvious visual cues to the reader about how the phenomenon is clustered or varies over space.

# %%
flights = sns.load_dataset("flights")
flights = flights.pivot("month", "year", "passengers")
flights
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
plt.figure(figsize=(10,7))
ax = sns.heatmap(flights,annot=True,fmt="d")

# %% [markdown]
# ###  Swarmplots
# ***
#
# They are used to draw a categorical scatterplot with non-overlapping points. A swarm plot can be drawn on its own, but it is also a good complement to a box or violin plot in cases where you want to show all observations along with some representation of the underlying distribution.

# %%
#Scactter on categorical is overlapping
sns.scatterplot(x=df['day'], y=df['total_bill'])
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
# Using TIPS Dataset
sns.swarmplot(x ="day", y = "total_bill", 
              data = df, size = 5)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ###  Countplot
# ***
#
# Count plots are used to show the counts of observations in each categorical bin using bars.

# %%
sns.countplot(x=df['sex'])
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# <br><br><br><br><br><br>
# ### Density Plot (KDE)
# ***
#
# Density plots are used to observe the distribution of a variable in a dataset. An advantage of Density Plots over Histograms is that they're better at determining the distribution shape because they're not affected by the number of bins.

# %%
sns.kdeplot(df['tip'])
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %% [markdown]
# <br><br><br><br><br><br>
# ###  Hexbin Plot
# ***
# A hexbin plot is useful to represent the relationship of 2 numerical variables when you have a lot of data points. Without overlapping of the points, the plotting window is split into several hexbins. The color of each hexbin denotes the number of points in it.

# %%
sns.jointplot(x='total_bill', y='tip',data=df, kind='hex',color="#019297")

# %% [markdown]
# ### Thank You !
